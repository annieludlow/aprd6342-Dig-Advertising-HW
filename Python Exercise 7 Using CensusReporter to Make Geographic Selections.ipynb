# %% [markdown]
# # Exercise 7 Census Reporter
# #Annie Ludlow

# %%
import requests
import csv
from time import sleep
import pandas as pd
import numpy as np
import warnings

#prevent error of api 
from tenacity import retry

#import csv file 
inputfile = open('msas.csv', 'r')
msas = csv.reader(inputfile)

#creating lists to store values from censusreporter
allcbsas = []
allnames = []
incomedemocount = []
hispanicdemocount = []
agedemocount = []

#tables 
tableids = ['B19001', 'B01001', 'B03002']
tableidstring = ','.join(tableids)
tableids

#parameter 1 HHincome 50k-74.9k
#parameter 2 18-34
#parameter 3 large hispanic populations 

#force retry 
@retry
def getdata(url):
    data = requests.get(url).json()
    return(data)
    
requesturl = 'http://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03002&geo_ids=310|01000US' 

loadedjson = requests.get(requesturl)


#for loop
count = 0
for msa in msas:
    count += 1
    #skipping header row of csv file
    if count != 1:

        #pull out cbsa, append to list
        cbsa = msa[0]
        
        allcbsas.append(cbsa)
        #pull out name of cbsa, append to list
        name = msa[1]
        allnames.append(name)
        
        #create url for a specific msa
        url = 'https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US%s' % (cbsa)
        print(url)
        #get data for cbsa
        data = getdata(url)


        # income (#1)
        # parse through the dictionary returned and get just the value we need
        inc = data['data']['31000US%s' % (cbsa)]['B19001']['estimate']
        inc50 = inc['B19001011']
        inc60 = inc['B19001012']
        totalincomecount = inc50 + inc60
        #write that value to the corresponding list of values
        incomedemocount.append(totalincomecount)
        
        # age (#2)
        # parse through the dictionary returned and get just the value we need
        age = data['data']['31000US%s' % (cbsa)]['B01001']['estimate']
        ageM18_19 = age['B01001007']
        ageM20 = age['B01001008']
        ageM21 = age['B01001009']
        ageM22_24 = age['B01001010']
        ageM25_29 = age['B01001011']
        ageM30_34 = age['B01001012']
        ageF18_19 = age['B01001031']
        ageF20 = age['B01001032']
        ageF21 = age['B01001033']
        ageF22_24 = age['B01001034']
        ageF25_29 = age['B01001035']
        ageF30_34 = age['B01001036']
        ageT = ageM18_19 + ageM20 + ageM21 + ageM22_24 + ageM25_29 + ageM30_34 \
            + ageF18_19 + ageF20 + ageF21 + ageF22_24 + ageF25_29 + ageF30_34
        #write that value to the corresponding list of values
        agedemocount.append(ageT)

        # hispanic (#3)
        # parse through the dictionary returned and get just the value we need
        pop_hisp = data['data']['31000US%s' % (cbsa)]['B03003']['estimate']['B03003003']
        #write that value to the corresponding list of values
        hispanicdemocount.append(pop_hisp)

#create a new dataframe
df = pd.DataFrame()

#write the lists to columns, one by one
df['cbsa'] = allcbsas
df['name'] = allnames
df['income'] = incomedemocount
df['hispanic'] = hispanicdemocount
df['age'] = agedemocount



#find out the max values
#max income
print('Q1: max income')
print('-------------------------')
df.iloc[df.income.argmax()]

#max age
print('Q2: max age')
print('-------------------------')
df.iloc[df.age.argmax()]

#max hispanic
print('Q3: max hispanic')
print('-------------------------')
df.iloc[df.hispanic.argmax()]


df['meanincome'] = df['income']/df['income'].max()
df['meanhispanic'] = df['hispanic']/df['hispanic'].max()                
df['meanage'] = df['age']/df['age'].max()  

#mean of the 3 means 
df['totalmean'] = (df['meanincome'] + df['meanhispanic'] + df['meanage']) / 3

#highest mean wins
print('Q4: highest cumulative mean')
print('-------------------------')
df.iloc[df.totalmean.argmax()]
# Out:
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US10900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US11700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US12980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US13980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14010
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US14860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15680
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US15980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US16980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US17980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US18020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US18140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US18580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US18700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US18880
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US19820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US20940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US21820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22520
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US22900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US23900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US24860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US25980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US26980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US27980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US28940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29200
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US29940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US30980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31080
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US31900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US32580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US32780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US32820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US32900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US33860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US34980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35840
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US35980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US36980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US37980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US38940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US39900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US40980
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41740
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41860
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US41940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42200
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42680
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US42700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US43900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44100
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US44940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45500
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45780
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45820
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US45940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46520
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US46700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47220
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47380
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47460
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47580
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US47940
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48060
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48140
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48260
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48300
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48540
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US48900
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49020
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49180
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49340
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49420
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49620
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49660
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49700
# https://api.censusreporter.org/1.0/data/show/latest?table_ids=B19001,B01001,B03003&geo_ids=31000US49740
# Q1: max income
# -------------------------
# Q2: max age
# -------------------------
# Q3: max hispanic
# -------------------------
# /Users/annieludlow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:121: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
# /Users/annieludlow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:126: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
# /Users/annieludlow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:131: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
# Q4: highest cumulative mean
# -------------------------
# /Users/annieludlow/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:147: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
# cbsa                                            35620
# name            New York-Newark-Jersey City, NY-NJ-PA
# income                                    1.03819e+06
# hispanic                                   4.9944e+06
# age                                       4.80694e+06
# meanincome                                          1
# meanhispanic                                 0.828053
# meanage                                             1
# totalmean                                    0.942684
# Name: 249, dtype: object
